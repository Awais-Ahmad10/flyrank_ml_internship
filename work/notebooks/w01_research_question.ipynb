# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Awais-Ahmad10/flyrank_ml_internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/Awais-Ahmad10/flyrank_ml_internship"
REPO_DIR = "flyrank_ml_internship"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

print("Current directory:", os.getcwd())
# Out:
# Current directory: /content/flyrank_ml_internship/flyrank_ml_internship

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I'm choosing Lane 2: Refresh / Content Opportunity Scoring. In Week 1, I already built a hand-written rule (stale + visible pages) and compared it against a learned model using Precision. This lane directly continues that same problem ranking pages so a reviewer knows which ones to look at first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# This work improves the decision of which pages a content reviewer should look at first, out of a large inventory, given limited review time each week. A content team member with limited capacity acts on this ranking.
#
# Cost of a wrong call: if a page is wrongly flagged as worth reviewing, it wastes a reviewer's limited time a low cost. If a genuinely declining page is never flagged, it keeps losing visibility unnoticed until it's much worse  a higher cost. Because missing real problems costs more than wasted review time, I care about both precision (are my top picks actually declining) and recall (am I missing real problems).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# Loading the starter dataset to check: how big is the declining pages problem, and is there a meaningful pool of high visibility pages worth prioritizing?

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
import pandas as pd, numpy as np

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
df["is_declining_label"] = df["trend_direction"].str.lower().eq("down").astype(int)

print("Total pages:", df.shape[0])
print("Declining rate:", round(df["is_declining_label"].mean(), 3))
print("Pages with meaningful impressions (>=500):", (df["impressions_90d"] >= 500).sum())
# Out:
# Total pages: 30000
# Declining rate: 0.542
# Pages with meaningful impressions (>=500): 16726

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# What I can say: this work will produce observed, directional evidence about which pages show signs of decline and which signals associate with it, and decision support rankings to help a reviewer prioritize limited time.
#
# What I will never claim:
# - That this proves anything about Google's ranking algorithm
# - That a refresh causes a page to recover  that requires a real experiment, not this data
# - That my declining label is a true future outcome  it's a proxy based on the current window, not a prediction of what happens next
# - That results from this 30,000-row starter sample necessarily hold at the full ~79M-row warehouse scale

# %%
# No code needed — explanation given above

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
